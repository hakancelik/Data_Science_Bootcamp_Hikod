# %% [markdown]
# <a href="https://www.kaggle.com/code/hakanelik/bg-nbd-and-gamma-gamma-cltv-prediction?scriptVersionId=164564308" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>
